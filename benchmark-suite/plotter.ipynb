# %%
from pretty_plot import *

# %% [markdown]
# ## 1. minisy vs. CVC4Sy

# %%
names, results_sygus = process_done('done_sygus.txt')
_, results_const = process_done('done_constraint.txt')

# %%
x = [results_sygus[name][0] for name in names]
y = [results_const[name][0] for name in names]

m = max([max(x), max(y)])
x = adjust(x, mx=m)
y = adjust(y, mx=m)

# %%
pretty_plot(x, y, x_name='FOSSIL[CVC4Sy]')

# %% [markdown]
# ## 2. minisy vs. streaming

# %%
names_stream, results_stream = process_done('done_streaming.txt')

# %%
x = [results_stream[name][0] for name in names_stream]
y = [results_const[name][0] for name in names_stream]

m = max([max(x), max(y)])
x = adjust(x, mx=m)
y = adjust(y, mx=m)

# %%
pretty_plot(x, y, x_name='FOSSIL[no-ce]')

# %% [markdown]
# ## 3. minisy vs. explicit grammar set production

# %%
names_grammar, results_grammar = process_done('done_grammar-sets.txt')

# %%
x = [results_grammar[name][0] for name in names_grammar]
y = [results_const[name][0] for name in names_grammar]

m = max([max(x), max(y)])
x = adjust(x, mx=m)
y = adjust(y, mx=m)

# %%
pretty_plot(x, y, x_name='FOSSIL[explicit-sets]')

# %% [markdown]
# ## 4. True models (10 vs. 0)

# %%
results_old = process_old('old_table.txt')

# %%
# Need to filter out tests for which both versions timed out
x = np.array([results_old[vc]['t0'] for vc in results_old
              if results_old[vc]['t0'] != -1 or results_old[vc]['t10'] != -1])
y = np.array([results_old[vc]['t10'] for vc in results_old
              if results_old[vc]['t0'] != -1 or results_old[vc]['t10'] != -1])

m = max([max(x), max(y)])
x = adjust(x, mx=m)
y = adjust(y, mx=m)

# %%
pretty_plot(x, y, x_name='0 true models', y_name='10 true models', y_leg='upper left')
